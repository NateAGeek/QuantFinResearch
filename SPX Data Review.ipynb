# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;
import talib as ta;
import mplfinance as mfin;

# %%
# SPX data for 2019, date/time, open,high,low,close
spx_data = pd.read_csv(
    './data/SPX_2019_1min.csv',
    header=None,
    names=["date", "open", "high", "low", "close"],
    parse_dates=["date"],
    index_col=['date']
    )
spx_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 97740 entries, 2019-01-02 09:30:00 to 2019-12-31 15:59:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    97740 non-null  float64
#  1   high    97740 non-null  float64
#  2   low     97740 non-null  float64
#  3   close   97740 non-null  float64
# dtypes: float64(4)
# memory usage: 3.7 MB

# %%
data = spx_data.head(75)
mfin.plot(data, type="candle")
